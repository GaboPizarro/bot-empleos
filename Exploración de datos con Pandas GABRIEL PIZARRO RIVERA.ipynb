# %%
import pandas as pd 
datos_ventas = { 
'Producto': ['Laptop', 'Mouse', 'Teclado', 'Monitor', 'Webcam', 
'Audífonos', 'Laptop', 'Mouse', 'Mouse'], 
'Categoría': ['Electrónica', 'Accesorios', 'Accesorios', 'Electrónica', 
'Accesorios', 'Accesorios', 'Electrónica', 'Accesorios', 'Accesorios'], 
'Precio': [1200, 25, 45, 300, 50, 75, 1250, 27, 26], 
'Unidades_Vendidas': [5, 30, 25, 10, 20, 15, 3, 40, 35] 
} 
df_ventas = pd.DataFrame(datos_ventas)

# %%
# Exploración inicial
print("Resumen DataFrame (info")
df_ventas.info()
print(df_ventas.head())

print("Resumen estadístico")
print(df_ventas.describe())
# Out:
# Resumen DataFrame (info
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Producto           9 non-null      object
#  1   Categoría          9 non-null      object
#  2   Precio             9 non-null      int64
#  3   Unidades_Vendidas  9 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 420.0+ bytes
#   Producto    Categoría  Precio  Unidades_Vendidas
# 0   Laptop  Electrónica    1200                  5
# 1    Mouse   Accesorios      25                 30
# 2  Teclado   Accesorios      45                 25
# 3  Monitor  Electrónica     300                 10
# 4   Webcam   Accesorios      50                 20
# Resumen estadístico
#             Precio  Unidades_Vendidas
# count     9.000000           9.000000
# mean    333.111111          20.333333
# std     513.080511          13.171940
# ...

# %%
# Selección y Filtrado
print("Columna Producto")
print(df_ventas['Producto'])

print("Columnas Producto y Precio")
print(df_ventas[['Producto', 'Precio']])

print("Ventas con Precio > 100")
print(df_ventas[df_ventas['Precio'] > 100])
# Out:
# Columna Producto
# 0       Laptop
# 1        Mouse
# 2      Teclado
# 3      Monitor
# 4       Webcam
# 5    Audífonos
# 6       Laptop
# 7        Mouse
# 8        Mouse
# Name: Producto, dtype: object
# Columnas Producto y Precio
#     Producto  Precio
# 0     Laptop    1200
# 1      Mouse      25
# 2    Teclado      45
# 3    Monitor     300
# 4     Webcam      50
# 5  Audífonos      75
# 6     Laptop    1250
# 7      Mouse      27
# 8      Mouse      26
# Ventas con Precio > 100
#   Producto    Categoría  Precio  Unidades_Vendidas
# 0   Laptop  Electrónica    1200                  5
# 3  Monitor  Electrónica     300                 10
# 6   Laptop  Electrónica    1250                  3

# %%
# Sumarización de Datos
print("Precio promedio")
print(df_ventas['Precio'].mean())

print("Productos vendidos categoría 'Accesorios'")
accesorios = df_ventas[df_ventas['Categoría'] == 'Accesorios']
print(accesorios['Unidades_Vendidas'].sum())

print("Frecuencia por producto")
print(df_ventas['Producto'].value_counts())
# Out:
# Precio promedio
# 333.1111111111111
# Productos vendidos categoría 'Accesorios'
# 165
# Frecuencia por producto
# Producto
# Mouse        3
# Laptop       2
# Teclado      1
# Monitor      1
# Webcam       1
# Audífonos    1
# Name: count, dtype: int64
